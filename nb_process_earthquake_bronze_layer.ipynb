# %%
from datetime import date, timedelta

start_date = date.today() - timedelta(7)
end_date = date.today() - timedelta(1)

url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
print(url)
# Out:
# StatementMeta(, 5989627f-620c-49b7-8c14-f16becd36576, 18, Finished, Available, Finished)
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2024-07-03&endtime=2024-07-09

# %%
import requests
# Out:
# StatementMeta(, 5989627f-620c-49b7-8c14-f16becd36576, 19, Finished, Available, Finished)

# %%
response = requests.get(url)
# Out:
# StatementMeta(, 5989627f-620c-49b7-8c14-f16becd36576, 20, Finished, Available, Finished)

# %%
import json

if response.status_code == 200:
    # get JSON response
    data = response.json()
    data = data['features']

    # specify path to save file
    file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json'

    # open the file in write mode ('W') and save the JSON data
    with open(file_path, 'w') as file:
        json.dump(data, file, indent = 4)
    
    print(f"Data saved successfully to {file_path}")

else:
    print("failed to fetch data. Status code:", response.status_code)
# Out:
# StatementMeta(, 5989627f-620c-49b7-8c14-f16becd36576, 21, Finished, Available, Finished)
# Data saved successfully to /lakehouse/default/Files/2024-07-03_earthquake_data.json

# %%
df = spark.read.option("multiline", "true").json("Files/2024-07-03_earthquake_data.json")
# df now is a Spark DataFrame containing JSON data from "Files/2024-07-03_earthquake_data.json".
display(df)
# Out:
# StatementMeta(, 5989627f-620c-49b7-8c14-f16becd36576, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ff151bd8-1afb-48e7-94b3-796e21ae818a)
